# %% [markdown]
# # PhysRevA.96.022128 - Figure 5
#
# Photon spectra

# %%
# import API
import pwpp
from pwpp import *

# %%
# for red curve in left column, chiphimod is also possible

fig, axes = plt.subplots(nrows=4, ncols=2,figsize=(10,10))
alphamrk = 0.3

xdim = 30
# tau
E0 = 1; #[GeV]
I21 = 3; #[]
lbd = 0.8; #[\mu m]
tau = 30 #[fs]
#
g0 = E0/m
a0 = 0.855*sqrt(I21*1e21/1e18)*lbd
w0 = 2*pi*c/(lbd*1e-6)*hbar/e*1e-9
n = tau*c/(lbd*1e-6)*1e-15
chi0 = 2*g0*a0* (hbar*2*pi*c/(lbd*1e-6)/e) /0.511e6
philst = np.linspace(-2*n,2*n,xdim)*2*pi
chiphilst = np.array([chiphi(g0,a0,w0, n, phi) for phi in philst])
axes[0,0].plot(philst/(2*pi*n),chiphilst,'k-')
axes[0,0].plot(philst/(2*pi*n),chi0*exp(-(philst**2/(2*pi**2*n**2/log(2)))),'r-')
#
f = open('data/fig5a1/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[0,0].plot(datatmp2[:,0],datatmp2[:,1],'r.', alpha=alphamrk)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[0,0].plot(datatmp2[:,0],datatmp2[:,1],'y.', alpha=alphamrk)
datatmp = data['datasetColl'][2]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[0,0].plot(datatmp2[:,0],datatmp2[:,1],'k.', alpha=alphamrk)
#
f = open('data/fig5a2/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[0,1].plot(datatmp2[:,0],datatmp2[:,1],'r.', alpha=alphamrk)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[0,1].plot(datatmp2[:,0],datatmp2[:,1],'y.', alpha=alphamrk)
datatmp = data['datasetColl'][2]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
wlst = np.linspace(0.01*E0,0.99*E0,xdim)
dNdwlst = np.array([dNgdw(g0,a0,w0,n,w)[0] for w in wlst])
axes[0,1].plot(wlst*1e3, dNdwlst/np.max(dNdwlst)*np.max(datatmp2[:,1])*3, 'k-')
axes[0,1].plot(datatmp2[:,0],datatmp2[:,1],'k.', alpha=alphamrk)
axes[0,1].set_ylim([1e-7,1e-2])

xdim = 30
# tau
E0 = 4; #[GeV]
I21 = 0.8; #[]
lbd = 0.8; #[\mu m]
tau = 40 #[fs]
#
g0 = E0/m
a0 = 0.855*sqrt(I21*1e21/1e18)*lbd
w0 = 2*pi*c/(lbd*1e-6)*hbar/e*1e-9
n = tau*c/(lbd*1e-6)*1e-15
chi0 = 2*g0*a0* (hbar*2*pi*c/(lbd*1e-6)/e) /0.511e6
philst = np.linspace(-2*n,2*n,xdim)*2*pi
chiphilst = np.array([chiphi(g0,a0,w0, n, phi) for phi in philst])
axes[1,0].plot(philst/(2*pi*n),chiphilst,'k-')
axes[1,0].plot(philst/(2*pi*n),chi0*exp(-(philst**2/(2*pi**2*n**2/log(2)))),'r-')
#
f = open('data/fig5b1/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[1,0].plot(datatmp2[:,0],datatmp2[:,1],'r.', alpha=alphamrk)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[1,0].plot(datatmp2[:,0],datatmp2[:,1],'y.', alpha=alphamrk)
datatmp = data['datasetColl'][2]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[1,0].plot(datatmp2[:,0],datatmp2[:,1],'k.', alpha=alphamrk)
#
f = open('data/fig5b2/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[1,1].plot(datatmp2[:,0],datatmp2[:,1],'r.', alpha=alphamrk)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[1,1].plot(datatmp2[:,0],datatmp2[:,1],'y.', alpha=alphamrk)
datatmp = data['datasetColl'][2]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
wlst = np.linspace(0.01*E0,0.99*E0,xdim)
dNdwlst = np.array([dNgdw(g0,a0,w0,n,w)[0] for w in wlst])
axes[1,1].plot(wlst*1e3, dNdwlst/np.max(dNdwlst)*np.max(datatmp2[:,1])*1.5, 'k-')
axes[1,1].plot(datatmp2[:,0],datatmp2[:,1],'k.', alpha=alphamrk)
axes[1,1].set_ylim([1e-7,1e-3])

##
# there is probably an incompatibility / issue with the time scale, since maximum chi seem to match
xdim = 30
# tau
E0 = 50; #[GeV]
I21 = 0.1; #[]
lbd = 1; #[\mu m]
tau = 100 #[fs]
#
g0 = E0/m
a0 = 0.855*sqrt(I21*1e21/1e18)*lbd
w0 = 2*pi*c/(lbd*1e-6)*hbar/e*1e-9
n = tau*c/(lbd*1e-6)*1e-15
chi0 = 2*g0*a0* (hbar*2*pi*c/(lbd*1e-6)/e) /0.511e6
philst = np.linspace(-2*n,2*n,xdim)*2*pi
chiphilst = np.array([chiphi(g0,a0,w0, n, phi) for phi in philst])
axes[2,0].plot(philst/(pi*n*sqrt(2)*2),chiphilst,'k-')
axes[2,0].plot(philst/(pi*n*sqrt(2)*2),chi0*exp(-(philst**2/(2*pi**2*n**2/log(2)))),'r-')
#
f = open('data/fig5c1/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[2,0].plot(datatmp2[:,0],datatmp2[:,1],'r.', alpha=alphamrk)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[2,0].plot(datatmp2[:,0],datatmp2[:,1],'y.', alpha=alphamrk)
datatmp = data['datasetColl'][2]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[2,0].plot(datatmp2[:,0],datatmp2[:,1],'k.', alpha=alphamrk)
#
f = open('data/fig5c2/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[2,1].plot(datatmp2[:,0],datatmp2[:,1],'r.', alpha=alphamrk)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
wlst = np.linspace(0.01*E0,0.99*E0,xdim)
dNdwlst = np.array([dNgdw(g0,a0,w0,n,w)[0] for w in wlst])
axes[2,1].plot(wlst, dNdwlst/np.max(dNdwlst)*np.max(datatmp2[:,1]), 'k-')
axes[2,1].plot(datatmp2[:,0],datatmp2[:,1],'k.', alpha=alphamrk)
datatmp = data['datasetColl'][2]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[2,1].plot(datatmp2[:,0],datatmp2[:,1],'y.', alpha=alphamrk)
axes[2,1].set_ylim([1e-7,1e-4])

xdim = 30
# tau
E0 = 4; #[GeV]
I21 = 100; #[]
lbd = 0.8; #[\mu m]
tau = 10 #[fs]
#
g0 = E0/m
a0 = 0.855*sqrt(I21*1e21/1e18)*lbd
w0 = 2*pi*c/(lbd*1e-6)*hbar/e*1e-9
n = tau*c/(lbd*1e-6)*1e-15
chi0 = 2*g0*a0* (hbar*2*pi*c/(lbd*1e-6)/e) /0.511e6
philst = np.linspace(-2*n,2*n,xdim)*2*pi
chiphilst = np.array([chiphi(g0,a0,w0, n, phi) for phi in philst])
axes[3,0].plot(philst/(2*pi*n),chiphilst,'k-')
axes[3,0].plot(philst/(2*pi*n),chi0*exp(-(philst**2/(2*pi**2*n**2/log(2)))),'r-')
#
f = open('data/fig5d1/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[3,0].plot(datatmp2[:,0],datatmp2[:,1],'r.', alpha=alphamrk)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[3,0].plot(datatmp2[:,0],datatmp2[:,1],'y.', alpha=alphamrk)
datatmp = data['datasetColl'][2]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[3,0].plot(datatmp2[:,0],datatmp2[:,1],'k.', alpha=alphamrk)
#
f = open('data/fig5d2/wpd.json')
data = json.load(f)
datatmp = data['datasetColl'][0]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[3,1].plot(datatmp2[:,0],datatmp2[:,1],'r.', alpha=alphamrk)
datatmp = data['datasetColl'][1]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
axes[3,1].plot(datatmp2[:,0],datatmp2[:,1],'y.', alpha=alphamrk)
datatmp = data['datasetColl'][2]['data']
datatmp2 = np.array([datatmp[i]['value'] for i in range(len(datatmp))])
wlst = np.linspace(0.01*E0,0.99*E0,xdim)
dNdwlst = np.array([dNgdw(g0,a0,w0,n,w)[0] for w in wlst])
axes[3,1].plot(wlst*1e3, dNdwlst/np.max(dNdwlst)*np.max(datatmp2[:,1]), 'k-')
axes[3,1].plot(datatmp2[:,0],datatmp2[:,1],'k.', alpha=alphamrk)
axes[3,1].set_ylim([1e-7,1e-2])


for i in range(4):
    axes[i,1].set_yscale('log')

plt.tight_layout()
plt.show()
